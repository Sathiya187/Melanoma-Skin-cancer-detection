# %%
import os

# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
import cv2

# %%
def resize_image(image, width=196, height=196):
    """
    Resize the input image to the specified width and height.
    """
    dim = (width, height)
    resized = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)
    return resized

input_dir = r"E:\Main Project\melanoma_cancer_dataset\test\benign"
output_dir = r"E:\Pre processing  and Segmentation\Melanoma\Test\benign"

def preprocess_image(image):
    """
    Preprocess the input image by removing noise and hair.
    """
    # Apply closing to remove noise and hair
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    closed = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
    
    return closed

def apply_otsu_segmentation(image):
    """
    Apply Otsu's thresholding to segment the image with a black background.
    """
    _, segmented = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    return segmented

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Iterate through images in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        
        # Read the image
        image = cv2.imread(input_path)
        
        # Preprocess the image (remove noise and hair)
        preprocessed_image = preprocess_image(image)
        
        # Convert preprocessed image to grayscale
        gray = cv2.cvtColor(preprocessed_image, cv2.COLOR_BGR2GRAY)
        
        # Resize the grayscale image
        resized_image = resize_image(gray, width=196, height=196)
        
        # Apply Otsu segmentation
        segmented_image = apply_otsu_segmentation(resized_image)
        
        # Save the segmented image to the output directory
        cv2.imwrite(output_path, segmented_image)
        print(f"Processed and saved: {output_path}")
# Out:
# Processed and saved: C:\Users\this pc\Desktop\pre\IMG-20240506-WA0001.jpg
# Processed and saved: C:\Users\this pc\Desktop\pre\IMG-20240506-WA0002.jpg

# %%
def resize_image(image, width=196, height=196):
    """
    Resize the input image to the specified width and height.
    """
    dim = (width, height)
    resized = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)
    return resized

input_dir = r"E:\Main Project\melanoma_cancer_dataset\test\malignant"
output_dir = r"E:\Pre processing  and Segmentation\Melanoma\Test\malignant"

def preprocess_image(image):
    """
    Preprocess the input image by removing noise and hair.
    """
    # Apply closing to remove noise and hair
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    closed = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
    
    return closed

def apply_otsu_segmentation(image):
    """
    Apply Otsu's thresholding to segment the image with a black background.
    """
    _, segmented = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    return segmented

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Iterate through images in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        
        # Read the image
        image = cv2.imread(input_path)
        
        # Preprocess the image (remove noise and hair)
        preprocessed_image = preprocess_image(image)
        
        # Convert preprocessed image to grayscale
        gray = cv2.cvtColor(preprocessed_image, cv2.COLOR_BGR2GRAY)
        
        # Resize the grayscale image
        resized_image = resize_image(gray, width=196, height=196)
        
        # Apply Otsu segmentation
        segmented_image = apply_otsu_segmentation(resized_image)
        
        # Save the segmented image to the output directory
        cv2.imwrite(output_path, segmented_image)
        print(f"Processed and saved: {output_path}")
# Out:
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Test\malignant\melanoma_10105.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Test\malignant\melanoma_10106.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Test\malignant\melanoma_10107.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Test\malignant\melanoma_10108.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Test\malignant\melanoma_10109.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Test\malignant\melanoma_10110.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Test\malignant\melanoma_10111.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Test\malignant\melanoma_10112.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Test\malignant\melanoma_10113.jpg
# ...

# %%
def resize_image(image, width=196, height=196):
    """
    Resize the input image to the specified width and height.
    """
    dim = (width, height)
    resized = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)
    return resized

input_dir = r"E:\Main Project\melanoma_cancer_dataset\train\benign"
output_dir = r"E:\Pre processing  and Segmentation\Melanoma\Train\benign"

def preprocess_image(image):
    """
    Preprocess the input image by removing noise and hair.
    """
    # Apply closing to remove noise and hair
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    closed = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
    
    return closed

def apply_otsu_segmentation(image):
    """
    Apply Otsu's thresholding to segment the image with a black background.
    """
    _, segmented = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    return segmented

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Iterate through images in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        
        # Read the image
        image = cv2.imread(input_path)
        
        # Preprocess the image (remove noise and hair)
        preprocessed_image = preprocess_image(image)
        
        # Convert preprocessed image to grayscale
        gray = cv2.cvtColor(preprocessed_image, cv2.COLOR_BGR2GRAY)
        
        # Resize the grayscale image
        resized_image = resize_image(gray, width=196, height=196)
        
        # Apply Otsu segmentation
        segmented_image = apply_otsu_segmentation(resized_image)
        
        # Save the segmented image to the output directory
        cv2.imwrite(output_path, segmented_image)
        print(f"Processed and saved: {output_path}")
# Out:
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_0.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_1.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_10.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_100.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_1000.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_1001.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_1002.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_1003.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_1004.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\benign\melanoma_1005.jpg
# ...

# %%
def resize_image(image, width=196, height=196):
    """
    Resize the input image to the specified width and height.
    """
    dim = (width, height)
    resized = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)
    return resized

input_dir = r"E:\Main Project\melanoma_cancer_dataset\train\malignant"
output_dir = r"E:\Pre processing  and Segmentation\Melanoma\Train\malignant"

def preprocess_image(image):
    """
    Preprocess the input image by removing noise and hair.
    """
    # Apply closing to remove noise and hair
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    closed = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
    
    return closed

def apply_otsu_segmentation(image):
    """
    Apply Otsu's thresholding to segment the image with a black background.
    """
    _, segmented = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    return segmented

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Iterate through images in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        
        # Read the image
        image = cv2.imread(input_path)
        
        # Preprocess the image (remove noise and hair)
        preprocessed_image = preprocess_image(image)
        
        # Convert preprocessed image to grayscale
        gray = cv2.cvtColor(preprocessed_image, cv2.COLOR_BGR2GRAY)
        
        # Resize the grayscale image
        resized_image = resize_image(gray, width=196, height=196)
        
        # Apply Otsu segmentation
        segmented_image = apply_otsu_segmentation(resized_image)
        
        # Save the segmented image to the output directory
        cv2.imwrite(output_path, segmented_image)
        print(f"Processed and saved: {output_path}")
# Out:
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\malignant\melanoma_5000.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\malignant\melanoma_5001.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\malignant\melanoma_5002.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\malignant\melanoma_5003.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\malignant\melanoma_5004.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\malignant\melanoma_5005.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\malignant\melanoma_5006.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\malignant\melanoma_5007.jpg
# Processed and saved: E:\Pre processing  and Segmentation\Melanoma\Train\malignant\melanoma_5008.jpg
# ...

# %%
# Function to extract features from an image
def extract_features(image):
   
    # we'll use ORB feature extractor
    orb = cv2.ORB_create()
    keypoints, descriptors = orb.detectAndCompute(image, None)
    return keypoints, descriptors

# Function to match features between two images
def match_features(descriptor1, descriptor2):
    # Implement feature matching algorithm
    # For example, you can use brute force matcher or FLANN matcher
    # Here, we'll use brute force matcher
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(descriptor1, descriptor2)
    matches = sorted(matches, key=lambda x: x.distance)
    return matches

# Set input and output directories
input_directory =r"E:\Preprocessing_and_Segmentation\Melanoma\Test\benign"
output_directory = r"E:\Feature Extraction\Melanoma\Test\benign"
threshold_value = 10  # Set your threshold value here

# Iterate through each image in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Read the image
        image_path = os.path.join(input_directory, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        # Extract features from the image
        keypoints, descriptors = extract_features(image)

        # Match features with images in the database
        # Here, you would iterate through your database of images and match features
        # For demonstration, let's assume we have a reference image already
        reference_image = cv2.imread("E:\Contour\download.jpg", cv2.IMREAD_GRAYSCALE)
        reference_keypoints, reference_descriptors = extract_features(reference_image)
        matches = match_features(descriptors, reference_descriptors)

        # Compute transformation related to the matching points
        # Here, you would implement RANSAC or some other method to eliminate outliers
        # For demonstration, let's assume we don't filter outliers
        num_matches = len(matches)

        if num_matches > threshold_value:
            print(f"Threshold value exceeded for {filename}. Number of matches: {num_matches}")

            # Save the image with extracted features to the output directory
            output_image_path = os.path.join(output_directory, filename)
            cv2.imwrite(output_image_path, image)

            print(f"Features extracted from {filename} and saved to {output_image_path}")
# Out:
# Threshold value exceeded for melanoma_10000.jpg. Number of matches: 21
# Features extracted from melanoma_10000.jpg and saved to E:\Feature Extraction\Melanoma\Test\benign\melanoma_10000.jpg
# Threshold value exceeded for melanoma_10001.jpg. Number of matches: 27
# Features extracted from melanoma_10001.jpg and saved to E:\Feature Extraction\Melanoma\Test\benign\melanoma_10001.jpg
# Threshold value exceeded for melanoma_10002.jpg. Number of matches: 28
# Features extracted from melanoma_10002.jpg and saved to E:\Feature Extraction\Melanoma\Test\benign\melanoma_10002.jpg
# Threshold value exceeded for melanoma_10003.jpg. Number of matches: 58
# Features extracted from melanoma_10003.jpg and saved to E:\Feature Extraction\Melanoma\Test\benign\melanoma_10003.jpg
# Threshold value exceeded for melanoma_10004.jpg. Number of matches: 30
# Features extracted from melanoma_10004.jpg and saved to E:\Feature Extraction\Melanoma\Test\benign\melanoma_10004.jpg
# ...

# %%
# Function to extract features from an image
def extract_features(image):
    # Implement your feature extraction algorithm here
    # For example, you can use ORB, SIFT, or any other feature extraction method
    # Here, we'll use ORB feature extractor
    orb = cv2.ORB_create()
    keypoints, descriptors = orb.detectAndCompute(image, None)
    return keypoints, descriptors

# Function to match features between two images
def match_features(descriptor1, descriptor2):
    # Implement feature matching algorithm
    # For example, you can use brute force matcher or FLANN matcher
    # Here, we'll use brute force matcher
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(descriptor1, descriptor2)
    matches = sorted(matches, key=lambda x: x.distance)
    return matches

# Set input and output directories
input_directory =r"E:\Preprocessing_and_Segmentation\Melanoma\Test\malignant"
output_directory = r"E:\Feature Extraction\Melanoma\Test\malignant"
threshold_value = 10  # Set your threshold value here

# Iterate through each image in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Read the image
        image_path = os.path.join(input_directory, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        # Extract features from the image
        keypoints, descriptors = extract_features(image)

        # Match features with images in the database
        # Here, you would iterate through your database of images and match features
        # For demonstration, let's assume we have a reference image already
        reference_image = cv2.imread("E:\Contour\download.jpg", cv2.IMREAD_GRAYSCALE)
        reference_keypoints, reference_descriptors = extract_features(reference_image)
        matches = match_features(descriptors, reference_descriptors)

        # Compute transformation related to the matching points
        # Here, you would implement RANSAC or some other method to eliminate outliers
        # For demonstration, let's assume we don't filter outliers
        num_matches = len(matches)

        if num_matches > threshold_value:
            print(f"Threshold value exceeded for {filename}. Number of matches: {num_matches}")

            # Save the image with extracted features to the output directory
            output_image_path = os.path.join(output_directory, filename)
            cv2.imwrite(output_image_path, image)

            print(f"Features extracted from {filename} and saved to {output_image_path}")
# Out:
# Threshold value exceeded for melanoma_10105.jpg. Number of matches: 36
# Features extracted from melanoma_10105.jpg and saved to E:\Feature Extraction\Melanoma\Test\malignant\melanoma_10105.jpg
# Threshold value exceeded for melanoma_10106.jpg. Number of matches: 36
# Features extracted from melanoma_10106.jpg and saved to E:\Feature Extraction\Melanoma\Test\malignant\melanoma_10106.jpg
# Threshold value exceeded for melanoma_10107.jpg. Number of matches: 73
# Features extracted from melanoma_10107.jpg and saved to E:\Feature Extraction\Melanoma\Test\malignant\melanoma_10107.jpg
# Threshold value exceeded for melanoma_10108.jpg. Number of matches: 21
# Features extracted from melanoma_10108.jpg and saved to E:\Feature Extraction\Melanoma\Test\malignant\melanoma_10108.jpg
# Threshold value exceeded for melanoma_10109.jpg. Number of matches: 73
# Features extracted from melanoma_10109.jpg and saved to E:\Feature Extraction\Melanoma\Test\malignant\melanoma_10109.jpg
# ...

# %%
# Function to extract features from an image
def extract_features(image):
    # Implement your feature extraction algorithm here
    # For example, you can use ORB, SIFT, or any other feature extraction method
    # Here, we'll use ORB feature extractor
    orb = cv2.ORB_create()
    keypoints, descriptors = orb.detectAndCompute(image, None)
    return keypoints, descriptors

# Function to match features between two images
def match_features(descriptor1, descriptor2):
    # Implement feature matching algorithm
    # For example, you can use brute force matcher or FLANN matcher
    # Here, we'll use brute force matcher
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(descriptor1, descriptor2)
    matches = sorted(matches, key=lambda x: x.distance)
    return matches

# Set input and output directories
input_directory =r"E:\Preprocessing_and_Segmentation\Melanoma\Train\benign"
output_directory = r"E:\Feature Extraction\Melanoma\Train\benign"
threshold_value = 10  # Set your threshold value here

# Iterate through each image in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Read the image
        image_path = os.path.join(input_directory, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        # Extract features from the image
        keypoints, descriptors = extract_features(image)

        # Match features with images in the database
        # Here, you would iterate through your database of images and match features
        # For demonstration, let's assume we have a reference image already
        reference_image = cv2.imread("E:\Contour\download.jpg", cv2.IMREAD_GRAYSCALE)
        reference_keypoints, reference_descriptors = extract_features(reference_image)
        matches = match_features(descriptors, reference_descriptors)

        # Compute transformation related to the matching points
        # Here, you would implement RANSAC or some other method to eliminate outliers
        # For demonstration, let's assume we don't filter outliers
        num_matches = len(matches)

        if num_matches > threshold_value:
            print(f"Threshold value exceeded for {filename}. Number of matches: {num_matches}")

            # Save the image with extracted features to the output directory
            output_image_path = os.path.join(output_directory, filename)
            cv2.imwrite(output_image_path, image)

            print(f"Features extracted from {filename} and saved to {output_image_path}")
# Out:
# Threshold value exceeded for melanoma_0.jpg. Number of matches: 12
# Features extracted from melanoma_0.jpg and saved to E:\Feature Extraction\Melanoma\Train\benign\melanoma_0.jpg
# Threshold value exceeded for melanoma_1.jpg. Number of matches: 38
# Features extracted from melanoma_1.jpg and saved to E:\Feature Extraction\Melanoma\Train\benign\melanoma_1.jpg
# Threshold value exceeded for melanoma_10.jpg. Number of matches: 23
# Features extracted from melanoma_10.jpg and saved to E:\Feature Extraction\Melanoma\Train\benign\melanoma_10.jpg
# Threshold value exceeded for melanoma_1001.jpg. Number of matches: 59
# Features extracted from melanoma_1001.jpg and saved to E:\Feature Extraction\Melanoma\Train\benign\melanoma_1001.jpg
# Threshold value exceeded for melanoma_1002.jpg. Number of matches: 65
# Features extracted from melanoma_1002.jpg and saved to E:\Feature Extraction\Melanoma\Train\benign\melanoma_1002.jpg
# ...

# %%
# Function to extract features from an image
def extract_features(image):
    # Implement your feature extraction algorithm here
    # For example, you can use ORB, SIFT, or any other feature extraction method
    # Here, we'll use ORB feature extractor
    orb = cv2.ORB_create()
    keypoints, descriptors = orb.detectAndCompute(image, None)
    return keypoints, descriptors

# Function to match features between two images
def match_features(descriptor1, descriptor2):
    # Implement feature matching algorithm
    # For example, you can use brute force matcher or FLANN matcher
    # Here, we'll use brute force matcher
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(descriptor1, descriptor2)
    matches = sorted(matches, key=lambda x: x.distance)
    return matches

# Set input and output directories
input_directory =r"E:\Preprocessing_and_Segmentation\Melanoma\Train\malignant"
output_directory = r"E:\Feature Extraction\Melanoma\Train\malignant"
threshold_value = 10  # Set your threshold value here

# Iterate through each image in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Read the image
        image_path = os.path.join(input_directory, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        # Extract features from the image
        keypoints, descriptors = extract_features(image)

        # Match features with images in the database
        # Here, you would iterate through your database of images and match features
        # For demonstration, let's assume we have a reference image already
        reference_image = cv2.imread("E:\Contour\download.jpg", cv2.IMREAD_GRAYSCALE)
        reference_keypoints, reference_descriptors = extract_features(reference_image)
        matches = match_features(descriptors, reference_descriptors)

        # Compute transformation related to the matching points
        # Here, you would implement RANSAC or some other method to eliminate outliers
        # For demonstration, let's assume we don't filter outliers
        num_matches = len(matches)

        if num_matches > threshold_value:
            print(f"Threshold value exceeded for {filename}. Number of matches: {num_matches}")

            # Save the image with extracted features to the output directory
            output_image_path = os.path.join(output_directory, filename)
            cv2.imwrite(output_image_path, image)

            print(f"Features extracted from {filename} and saved to {output_image_path}")
# Out:
# Threshold value exceeded for melanoma_5000.jpg. Number of matches: 30
# Features extracted from melanoma_5000.jpg and saved to E:\Feature Extraction\Melanoma\Train\malignant\melanoma_5000.jpg
# Threshold value exceeded for melanoma_5003.jpg. Number of matches: 37
# Features extracted from melanoma_5003.jpg and saved to E:\Feature Extraction\Melanoma\Train\malignant\melanoma_5003.jpg
# Threshold value exceeded for melanoma_5004.jpg. Number of matches: 37
# Features extracted from melanoma_5004.jpg and saved to E:\Feature Extraction\Melanoma\Train\malignant\melanoma_5004.jpg
# Threshold value exceeded for melanoma_5005.jpg. Number of matches: 71
# Features extracted from melanoma_5005.jpg and saved to E:\Feature Extraction\Melanoma\Train\malignant\melanoma_5005.jpg
# Threshold value exceeded for melanoma_5006.jpg. Number of matches: 33
# Features extracted from melanoma_5006.jpg and saved to E:\Feature Extraction\Melanoma\Train\malignant\melanoma_5006.jpg
# ...
